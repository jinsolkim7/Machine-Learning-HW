# %% [markdown]
# ### 데이터 불러오기

# %%
import numpy as np

x_train = np.loadtxt('./hw1_data/p1_train_input.txt')
y_train = np.loadtxt('./hw1_data/p1_train_target.txt')
x_test = np.loadtxt('./hw1_data/p1_test_input.txt')
y_test = np.loadtxt('./hw1_data/p1_test_target.txt')

# %%
x_train.shape
# Out:
# (225, 2)

# %% [markdown]
# ### 데이터 구성 확인

# %%
import pandas as pd

# %%
x_train
# Out:
# array([[ 0.9003,  0.3746],
#        [-0.5377, -0.3078],
#        [ 0.2137, -0.6679],
#        [-0.028 , -0.6888],
#        [ 0.7826, -0.6178],
#        [ 0.5242, -0.1551],
#        [-0.0871,  0.712 ],
#        [-0.963 , -0.0195],
#        [ 0.6428,  0.6319],
#        [-0.1106, -0.0785],
#        [ 0.2309, -0.0853],
#        [ 0.5839, -0.0986],
#        [ 0.8436, -0.1756],
#        [ 0.4764,  0.8032],
#        [-0.6475, -0.9888],
#        [-0.1886, -0.4052],
#        [ 0.8709, -0.9017],
#        [ 0.8338,  0.3864],
#        [-0.1795,  0.3002],
#        [ 0.7873,  0.966 ],
#        [-0.8842,  0.1053],
#        [-0.2943, -0.1999],
#        [ 0.6263, -0.6024],
#        [-0.9803,  0.2504],
#        [-0.7222,  0.4667],
#        [-0.5945, -0.2482],
#        [-0.6026, -0.9802],
#        [ 0.2076, -0.1603],
#        [-0.4556,  0.5073],
#        [-0.6024,  0.5877],
#        [-0.9695,  0.8399],
#        [ 0.4936,  0.6894],
#        [-0.1098, -0.2645],
#        [ 0.8636,  0.2416],
# ...

# %%
x_train[:, 0]
# Out:
# array([ 0.9003, -0.5377,  0.2137, -0.028 ,  0.7826,  0.5242, -0.0871,
#        -0.963 ,  0.6428, -0.1106,  0.2309,  0.5839,  0.8436,  0.4764,
#        -0.6475, -0.1886,  0.8709,  0.8338, -0.1795,  0.7873, -0.8842,
#        -0.2943,  0.6263, -0.9803, -0.7222, -0.5945, -0.6026,  0.2076,
#        -0.4556, -0.6024, -0.9695,  0.4936, -0.1098,  0.8636, -0.068 ,
#        -0.1627,  0.6924,  0.0503, -0.5947,  0.3443,  0.6762, -0.9607,
#         0.3626, -0.241 ,  0.6636,  0.0056,  0.4189, -0.1422, -0.3908,
#        -0.6207, -0.6131,  0.3644, -0.3945,  0.0833, -0.6983,  0.3958,
#        -0.2433,  0.72  ,  0.7073,  0.1871, -0.0069,  0.7995,  0.6433,
#         0.2898,  0.6359,  0.3205, -0.3161, -0.4205, -0.3176,  0.0682,
#         0.4542, -0.3814,  0.677 ,  0.1361, -0.2592,  0.4055,  0.0931,
#        -0.1102,  0.3891,  0.2426,  0.5896,  0.9137,  0.0452,  0.7603,
#        -0.6541,  0.9595, -0.4571, -0.4953,  0.7515,  0.4746, -0.727 ,
# ...

# %%
x_train[:, 1]
# Out:
# array([ 0.3746, -0.3078, -0.6679, -0.6888, -0.6178, -0.1551,  0.712 ,
#        -0.0195,  0.6319, -0.0785, -0.0853, -0.0986, -0.1756,  0.8032,
#        -0.9888, -0.4052, -0.9017,  0.3864,  0.3002,  0.966 ,  0.1053,
#        -0.1999, -0.6024,  0.2504,  0.4667, -0.2482, -0.9802, -0.1603,
#         0.5073,  0.5877,  0.8399,  0.6894, -0.2645,  0.2416,  0.4626,
#        -0.6122,  0.8096,  0.1384,  0.2636, -0.5312,  0.0976,  0.8632,
#        -0.3296,  0.3111, -0.2162,  0.2546,  0.3982, -0.2056, -0.1727,
#         0.3104,  0.6752, -0.2568, -0.1495,  0.1893,  0.1315,  0.4331,
#         0.0226,  0.5528, -0.0213, -0.6282,  0.4013,  0.9654,  0.6133,
#         0.4071, -0.0301, -0.7708,  0.3297, -0.2693, -0.7199,  0.1335,
#         0.646 ,  0.3479,  0.9989,  0.9233, -0.8823, -0.2794,  0.097 ,
#        -0.4765,  0.1947, -0.9014,  0.1421,  0.4017,  0.9246,  0.501 ,
#         0.48  , -0.1363,  0.2685,  0.6061, -0.8322,  0.8909,  0.8319,
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plt.title('Scatter Plot')
plt.xlabel('x1')
plt.ylabel
# Out:
# <function matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, **kwargs)>

# %% [markdown]
# ### 모델 만들기

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
svm = SVC(kernel='rbf', C=10.0, gamma=10, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.9156

# %%
svm
# Out:
# SVC(C=10.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=10, kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    """Plot the decision function for a 2D SVC"""
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)
    
    # plot decision boundary and margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    
    # plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none')

# %% [markdown]
# ### (여기부터는) 파라미터 변경

# %%
svm = SVC(kernel='rbf', C=1.0, gamma=10, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.9022

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
svm = SVC(kernel='rbf', C=1.0, gamma=100, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.9111

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
svm = SVC(kernel='rbf', C=1.0, gamma=1000, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.7422

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
svm = SVC(kernel='rbf', C=10.0, gamma=100, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.8978

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
svm = SVC(kernel='rbf', C=10.0, gamma=1000, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.7467

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
svm = SVC(kernel='rbf', C=100.0, gamma=10, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.8933

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
svm = SVC(kernel='sigmoid', C=100.0, gamma=1000, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.4800

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');

# %%
svm = SVC(kernel='rbf', C=1000, gamma=1)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.8044

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none');
