# %% [markdown]
# ### 데이터 불러오기

# %%
import numpy as np

x_train = np.loadtxt('./hw1_data/p2_train_input.txt')
y_train = np.loadtxt('./hw1_data/p2_train_target.txt')
x_test = np.loadtxt('./hw1_data/p2_test_input.txt')
y_test = np.loadtxt('./hw1_data/p2_test_target.txt')

# %%
x_train.shape
# Out:
# (220, 2)

# %% [markdown]
# ### 데이터 구성 확인

# %%
import pandas as pd

# %%
x_train
# Out:
# array([[-0.464639  , -0.121145  ],
#        [ 0.135472  , -0.889568  ],
#        [ 0.970078  , -0.171183  ],
#        [ 0.82157   , -0.753442  ],
#        [ 0.612887  ,  0.683124  ],
#        [-0.297735  , -0.168541  ],
#        [-0.00248002, -0.852843  ],
#        [ 0.985399  ,  0.170755  ],
#        [-0.207504  ,  0.751678  ],
#        [-0.504063  , -0.0378516 ],
#        [ 0.0117563 ,  0.800893  ],
#        [-0.236184  , -0.949753  ],
#        [ 0.934137  ,  0.643015  ],
#        [ 0.0455113 ,  0.810166  ],
#        [ 1.13604   , -0.292749  ],
#        [ 0.664256  ,  0.794342  ],
#        [ 1.22243   ,  0.348832  ],
#        [-0.482986  ,  0.28873   ],
#        [ 0.866396  , -0.224005  ],
#        [-0.338697  , -0.724189  ],
#        [ 0.320635  ,  0.995362  ],
#        [ 0.744844  ,  0.658563  ],
#        [-0.231568  ,  0.854201  ],
#        [ 0.269892  ,  0.889434  ],
#        [-0.0633186 ,  0.994509  ],
#        [ 1.15142   ,  0.0718366 ],
#        [ 0.946472  ,  0.610551  ],
#        [-0.188315  , -0.887038  ],
#        [ 0.621727  , -0.902487  ],
#        [ 0.728013  , -0.560106  ],
#        [ 0.320426  ,  0.825575  ],
#        [-0.529721  ,  0.0425225 ],
#        [ 1.21527   , -0.138081  ],
#        [ 0.0842994 ,  0.986783  ],
#        [ 1.01331   , -0.19764   ],
#        [ 0.975239  ,  0.113096  ],
#        [-0.327472  ,  0.492194  ],
#        [ 0.726546  , -0.579295  ],
#        [-0.1353    ,  0.903109  ],
#        [ 1.22774   ,  0.175219  ],
#        [ 1.00454   , -0.419099  ],
#        [ 0.998153  , -0.197797  ],
#        [ 0.482345  , -0.716278  ],
#        [ 0.875465  , -0.516128  ],
#        [-0.461579  ,  0.64888   ],
#        [ 0.156712  ,  0.981631  ],
#        [ 1.02053   , -0.208577  ],
#        [-0.504146  ,  0.244309  ],
#        [ 0.210006  ,  0.906221  ],
#        [-0.565923  ,  0.0621384 ],
#        [-0.0196953 , -0.40671   ],
#        [ 0.816039  , -0.491902  ],
#        [ 0.778678  ,  0.712839  ],
#        [ 1.1408    ,  0.0646497 ],
#        [ 0.483952  ,  0.223149  ],
#        [-0.267388  , -0.142972  ],
#        [-0.13478   ,  0.879861  ],
#        [ 0.69494   ,  0.757657  ],
#        [ 1.09422   ,  0.320138  ],
#        [ 0.509449  , -0.950424  ],
#        [ 0.695857  ,  0.747142  ],
#        [-0.189219  , -0.933308  ],
#        [-0.0680874 , -0.846675  ],
#        [ 0.877051  , -0.660692  ],
#        [-0.279008  ,  0.687062  ],
#        [-0.468514  ,  0.108445  ],
#         0.296252  ,  0.670531  , -0.0734547 , -0.00560467, -0.250886  ,
#         0.691581  ,  0.34074   , -0.538559  , -0.633758  ,  0.328337  ,
#         0.435062  , -0.526269  ,  0.430118  ,  1.30465   ,  1.30748   ,
#         0.71216   , -0.387164  ,  0.653458  ,  1.23044   ,  0.279132  ,
#        -0.548025  ,  0.812871  ,  0.286141  , -0.697951  , -0.0248748 ,
#        -0.375714  , -0.694808  , -0.711635  ,  0.132553  ,  0.85223   ,
#         0.645821  ,  0.448812  ,  0.390605  , -0.452286  ,  0.475307  ,
#         1.2163    ,  0.781826  ,  0.673864  ,  1.18629   ,  0.600402  ,
#         0.0321516 ,  0.485505  , -0.224055  ,  0.381365  , -0.577212  ,
#         0.930208  ,  0.38413   ,  0.879801  ,  0.583121  , -0.616884  ,
#         1.22507   ,  0.659521  ,  1.12354   ,  0.926166  ,  0.265483  ])

# %%
import matplotlib.pyplot as plt

plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plt.title('Scatter Plot')
plt.xlabel('x1')
plt.ylabel
# Out:
# <function matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, **kwargs)>

# %% [markdown]
# ### 모델 만들기

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
svm = SVC(kernel='rbf', C=10.0, gamma=10, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.9409

# %%
svm
# Out:
# SVC(C=10.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=10, kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
def plot_svc_decision_function(model, ax=None, plot_support=True):
    """Plot the decision function for a 2D SVC"""
    if ax is None:
        ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    # create grid to evaluate model
    x = np.linspace(xlim[0], xlim[1], 30)
    y = np.linspace(ylim[0], ylim[1], 30)
    Y, X = np.meshgrid(y, x)
    xy = np.vstack([X.ravel(), Y.ravel()]).T
    P = model.decision_function(xy).reshape(X.shape)
    
    # plot decision boundary and margins
    ax.contour(X, Y, P, colors='k',
               levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    
    # plot support vectors
    if plot_support:
        ax.scatter(model.support_vectors_[:, 0],
                   model.support_vectors_[:, 1],
                   s=300, linewidth=1, facecolors='none');
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none')

# %%
svm = SVC(kernel='rbf', C=14.0, gamma=9, random_state=0)
svm.fit(x_train, y_train)
y_pred_ksvc = svm.predict(x_test)
print('Accuracy: %.4f' % accuracy_score(y_test, y_pred_ksvc))
# Out:
# Accuracy: 0.9318

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, s=20, cmap='rainbow')
plot_svc_decision_function(svm)
plt.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1],
            s=300, lw=1, facecolors='none')
